# %%
# importing all libraries
import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# data loading and reading
df = pd.read_csv("/content/drive/MyDrive/ionosphere_data.csv")
df.head()
# Out:
#    feature1  feature2  feature3  ...  feature33  feature34  label
# 0         1         0   0.99539  ...    0.18641   -0.45300      g
# 1         1         0   1.00000  ...   -0.13738   -0.02447      b
# 2         1         0   1.00000  ...    0.56045   -0.38238      g
# 3         1         0   1.00000  ...   -0.32382    1.00000      b
# 4         1         0   1.00000  ...   -0.04608   -0.65697      g
#
# [5 rows x 35 columns]

# %%
# check labels counts 
df1 =df['label']
df1.value_counts()
# Out:
# g    225
# b    126
# Name: label, dtype: int64

# %%
# randomly dataframe check
df.sample(5)
# Out:
#      feature1  feature2  feature3  ...  feature33  feature34  label
# 330         1         0   0.82624  ...    0.92553    0.00000      g
# 185         1         0   0.84177  ...   -0.00422    0.69409      g
# 81          0         0   1.00000  ...    1.00000   -1.00000      b
# 159         1         0   0.94333  ...   -0.21572    0.50457      g
# 347         1         0   0.95113  ...    0.91483    0.04712      g
#
# [5 rows x 35 columns]

# %%
# check duplicted values
df.duplicated().sum()
# Out:
# 1

# %%
# remove duplicated values
df.drop_duplicates()
# Out:
#      feature1  feature2  feature3  ...  feature33  feature34  label
# 0           1         0   0.99539  ...    0.18641   -0.45300      g
# 1           1         0   1.00000  ...   -0.13738   -0.02447      b
# 2           1         0   1.00000  ...    0.56045   -0.38238      g
# 3           1         0   1.00000  ...   -0.32382    1.00000      b
# 4           1         0   1.00000  ...   -0.04608   -0.65697      g
# ..        ...       ...       ...  ...        ...        ...    ...
# 346         1         0   0.83508  ...    0.90546   -0.04307      g
# 347         1         0   0.95113  ...    0.91483    0.04712      g
# 348         1         0   0.94701  ...    0.92697   -0.00577      g
# 349         1         0   0.90608  ...    0.87403   -0.16243      g
# 350         1         0   0.84710  ...    0.85764   -0.06151      g
#
# [350 rows x 35 columns]

# %%
# dataframe shape
df.shape
# Out:
# (351, 35)

# %%
#check na values in dataframe
df.isna().sum()
# Out:
# feature1     0
# feature2     0
# feature3     0
# feature4     0
# feature5     0
# feature6     0
# feature7     0
# feature8     0
# feature9     0
# feature10    0
# feature11    0
# feature12    0
# feature13    0
# feature14    0
# feature15    0
# feature16    0
# feature17    0
# feature18    0
# feature19    0
# feature20    0
# feature21    0
# feature22    0
# feature23    0
# feature24    0
# feature25    0
# feature26    0
# feature27    0
# feature28    0
# feature29    0
# feature30    0
# feature31    0
# feature32    0
# feature33    0
# feature34    0
# label        0
# dtype: int64

# %%
# check dataframe information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 351 entries, 0 to 350
# Data columns (total 35 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   feature1   351 non-null    int64
#  1   feature2   351 non-null    int64
#  2   feature3   351 non-null    float64
#  3   feature4   351 non-null    float64
#  4   feature5   351 non-null    float64
#  5   feature6   351 non-null    float64
#  6   feature7   351 non-null    float64
#  7   feature8   351 non-null    float64
#  8   feature9   351 non-null    float64
#  9   feature10  351 non-null    float64
#  10  feature11  351 non-null    float64
#  11  feature12  351 non-null    float64
#  12  feature13  351 non-null    float64
#  13  feature14  351 non-null    float64
#  14  feature15  351 non-null    float64
#  15  feature16  351 non-null    float64
#  16  feature17  351 non-null    float64
#  17  feature18  351 non-null    float64
#  18  feature19  351 non-null    float64
#  19  feature20  351 non-null    float64
#  20  feature21  351 non-null    float64
#  21  feature22  351 non-null    float64
#  22  feature23  351 non-null    float64
#  23  feature24  351 non-null    float64
#  24  feature25  351 non-null    float64
#  25  feature26  351 non-null    float64
#  26  feature27  351 non-null    float64
#  27  feature28  351 non-null    float64
#  28  feature29  351 non-null    float64
#  29  feature30  351 non-null    float64
#  30  feature31  351 non-null    float64
#  31  feature32  351 non-null    float64
#  32  feature33  351 non-null    float64
#  33  feature34  351 non-null    float64
#  34  label      351 non-null    object
# dtypes: float64(32), int64(2), object(1)
# memory usage: 96.1+ KB

# %%
# check statistcal description
df.describe()
# Out:
#          feature1  feature2    feature3  ...   feature32   feature33   feature34
# count  351.000000     351.0  351.000000  ...  351.000000  351.000000  351.000000
# mean     0.891738       0.0    0.641342  ...   -0.003794    0.349364    0.014480
# std      0.311155       0.0    0.497708  ...    0.513574    0.522663    0.468337
# min      0.000000       0.0   -1.000000  ...   -1.000000   -1.000000   -1.000000
# 25%      1.000000       0.0    0.472135  ...   -0.242595    0.000000   -0.165350
# 50%      1.000000       0.0    0.871110  ...    0.000000    0.409560    0.000000
# 75%      1.000000       0.0    1.000000  ...    0.200120    0.813765    0.171660
# max      1.000000       0.0    1.000000  ...    1.000000    1.000000    1.000000
#
# [8 rows x 34 columns]

# %%
#dataframe spliting into data & label
data=df.iloc[:,:-1]
label=df.iloc[:,-1]

# %%
#label encoding with the maping function
label = df["label"].map({'g':1,'b':0})

# %%
#check data (input) shape
data.shape
# Out:
# (351, 34)

# %%
#check label(output) shape
label.shape
# Out:
# (351,)

# %%
#data & label spliting into train & test
X_train=data.sample(frac=0.6,random_state=1)
X_test=data.sample(frac=0.4,random_state=1)
y_train=label.sample(frac=0.6,random_state=1)
y_test=label.sample(frac=0.4,random_state=1)

# %%
# train data shape
X_train.shape
# Out:
# (211, 34)

# %%
#test data shape
X_test.shape
# Out:
# (140, 34)

# %%
y_test.shape
# Out:
# (140,)

# %%
#training and test data & label convert into numpy array 
X_train=np.asarray(X_train).astype("float32")
X_test=np.asarray(X_test).astype("float32")
#y_train=np.asarray(X_train).astype("float32")
#y_test=np.asarray(y_test).astype("float32")

# %%
#model building
from keras import models, layers , optimizers ,regularizers,losses
network=models.Sequential()
network.add(layers.Dense(16,activation="relu",input_shape=(X_train.shape[1],)))
#network.add(layers.Dense(8,kernel_regularizer=regularizers.l2(0.0001),activation="relu"))
network.add(layers.Dense(1,activation="sigmoid"))

# %%
# model summary
network.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_10 (Dense)             (None, 16)                560
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 17
# =================================================================
# Total params: 577
# Trainable params: 577
# Non-trainable params: 0
# _________________________________________________________________

# %%
#model compiling
network.compile(optimizer="rmsprop",loss="binary_crossentropy",metrics=["accuracy"])

# %%
#model training
history = network.fit(X_train,y_train,epochs=50,batch_size=1,verbose=1)
# Out:
# Epoch 1/50
# 211/211 [==============================] - 1s 904us/step - loss: 0.6292 - accuracy: 0.7167
# Epoch 2/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.5439 - accuracy: 0.7684
# Epoch 3/50
# 211/211 [==============================] - 0s 932us/step - loss: 0.4779 - accuracy: 0.8261
# Epoch 4/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.5050 - accuracy: 0.8499
# Epoch 5/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.3744 - accuracy: 0.8578
# Epoch 6/50
# 211/211 [==============================] - 0s 957us/step - loss: 0.3506 - accuracy: 0.8968
# Epoch 7/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.3261 - accuracy: 0.8972
# Epoch 8/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.2787 - accuracy: 0.8942
# Epoch 9/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.3600 - accuracy: 0.8800
# Epoch 10/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.3175 - accuracy: 0.8810
# Epoch 11/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.2551 - accuracy: 0.9156
# Epoch 12/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.2400 - accuracy: 0.9247
# Epoch 13/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.2488 - accuracy: 0.9163
# Epoch 14/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.2320 - accuracy: 0.9250
# Epoch 15/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.1802 - accuracy: 0.9373
# Epoch 16/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.2057 - accuracy: 0.9213
# Epoch 17/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.2207 - accuracy: 0.9161
# Epoch 18/50
# 211/211 [==============================] - 0s 950us/step - loss: 0.1867 - accuracy: 0.9424
# Epoch 19/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.1371 - accuracy: 0.9606
# Epoch 20/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.1861 - accuracy: 0.9438
# Epoch 21/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.2980 - accuracy: 0.8959
# Epoch 22/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.1662 - accuracy: 0.9457
# Epoch 23/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.1242 - accuracy: 0.9576
# Epoch 24/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.0925 - accuracy: 0.9729
# Epoch 25/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.1384 - accuracy: 0.9610
# Epoch 26/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.1437 - accuracy: 0.9607
# Epoch 27/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.1456 - accuracy: 0.9449
# Epoch 28/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.0773 - accuracy: 0.9832
# Epoch 29/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.1309 - accuracy: 0.9502
# Epoch 30/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.0807 - accuracy: 0.9815
# Epoch 31/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.1080 - accuracy: 0.9657
# Epoch 32/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.0576 - accuracy: 0.9810
# Epoch 33/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.1177 - accuracy: 0.9368
# Epoch 34/50
# 211/211 [==============================] - 0s 938us/step - loss: 0.0914 - accuracy: 0.9732
# Epoch 35/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.0853 - accuracy: 0.9752
# Epoch 36/50
# 211/211 [==============================] - 0s 921us/step - loss: 0.0922 - accuracy: 0.9785
# Epoch 37/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.0908 - accuracy: 0.9722
# Epoch 38/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.1177 - accuracy: 0.9566
# Epoch 39/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.1466 - accuracy: 0.9549
# Epoch 40/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.0732 - accuracy: 0.9748
# Epoch 41/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.0759 - accuracy: 0.9785
# Epoch 42/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.0559 - accuracy: 0.9810
# Epoch 43/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.1014 - accuracy: 0.9647
# Epoch 44/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.0867 - accuracy: 0.9736
# Epoch 45/50
# 211/211 [==============================] - 0s 968us/step - loss: 0.0666 - accuracy: 0.9838
# Epoch 46/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.0797 - accuracy: 0.9810
# Epoch 47/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.0523 - accuracy: 0.9828
# Epoch 48/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.0988 - accuracy: 0.9685
# Epoch 49/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.0971 - accuracy: 0.9662
# Epoch 50/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.1067 - accuracy: 0.9641

# %%
history_dict = history.history
history_dict.keys()
[u'accuracy', u'loss']
# Out:
# ['accuracy', 'loss']

# %%
loss_acc=pd.DataFrame(history.history)
loss_acc.tail().T
# Out:
#                 45        46        47        48        49
# loss      0.085822  0.086351  0.078823  0.082679  0.073961
# accuracy  0.971564  0.971564  0.971564  0.971564  0.976303

# %%
#Accuracy and loss represntation
import matplotlib.pyplot as plt
history_dict = history.history
loss_values = history_dict['loss']
accuracy_values = history_dict['accuracy']
epochs = range(1, len(history_dict['accuracy']) + 1)
plt.plot(epochs, loss_values, 'g', label='loss')
plt.plot(epochs, accuracy_values, 'b', label='accuracy')
plt.title('Accuracy & Loss ')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid()
plt.show()

# %%
#network evaluation
network.evaluate(X_test,y_test)
# Out:
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0632 - accuracy: 0.9786
# [0.06318449974060059, 0.9785714149475098]

# %%
# model prediction
pred=network.predict(X_test)
pred.flatten().astype("U8")
# Out:
# array(['0.003596', '0.999456', '4.952405', '0.999599', '0.929617',
#        '0.999535', '0.999034', '0.969878', '0.002274', '0.070768',
#        '0.998106', '0.999518', '0.006790', '0.997188', '9.844845',
#        '0.011373', '0.871483', '0.005247', '0.992852', '9.462907',
#        '0.830632', '0.954067', '0.999214', '0.974938', '2.616103',
#        '0.998943', '0.996871', '0.999059', '0.971674', '0.999172',
#        '0.000419', '0.999428', '0.001089', '0.042947', '0.998605',
#        '0.998851', '0.043884', '1.582683', '0.999081', '0.999793',
#        '0.989533', '0.996741', '0.993241', '0.997896', '0.999633',
#        '0.968992', '0.998634', '0.997028', '0.059039', '0.997398',
#        '0.962703', '0.999677', '0.092705', '0.002108', '0.999756',
#        '0.996085', '0.001864', '6.634718', '5.547362', '0.998648',
#        '0.997692', '0.000603', '0.999499', '0.000962', '0.000351',
#        '0.997046', '1.429206', '0.999633', '0.998253', '7.843450',
#        '0.998571', '0.006119', '8.544027', '0.999423', '0.008403',
#        '1.047882', '0.999243', '0.997794', '0.998101', '0.988036',
#        '0.978266', '0.999903', '0.997145', '0.999804', '0.999691',
#        '0.999409', '0.997517', '0.997185', '0.989572', '0.998098',
#        '0.990307', '5.710306', '0.000275', '0.989712', '0.999195',
#        '0.001180', '0.998550', '0.998027', '0.995598', '0.998157',
#        '0.998397', '0.000156', '0.986134', '0.999070', '0.998764',
#        '0.865021', '1.748582', '0.999001', '0.999941', '0.996079',
#        '0.999737', '0.998037', '0.932499', '0.998245', '0.999621',
#        '0.992246', '0.000195', '0.998574', '4.761993', '0.994388',
#        '0.999457', '0.923561', '1.927743', '0.991006', '0.993086',
#        '0.013393', '0.991200', '0.001915', '0.999363', '0.999496',
#        '0.999073', '0.999797', '0.934859', '0.002679', '0.999406',
#        '0.000554', '0.988866', '0.000224', '0.999278', '2.915451'],
#       dtype='<U8')
